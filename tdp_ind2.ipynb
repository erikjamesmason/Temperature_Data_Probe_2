# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
import pathlib
import calendar
import pickle

# %% [markdown]
# ## Read .csv

# %%
#df1 = pd.read_pickle('tdp_ind.pkl')

df1 = pd.read_csv('tdp_ind.csv', infer_datetime_format=True)

# work on preserving site number as object
# rerun date time function

# %% [markdown]
# ## Configure Date Time

# %%
df1.OBSERVATION_TIME = pd.to_datetime(df1.OBSERVATION_TIME)

# %% [markdown]
# ## Set MultiIndex

# %%
df1 = df1.set_index(['SITE_NUMBER', 'OBSERVATION_TIME'])

# datetimeindex = pd.to_datetime(df1.index.levels[1])

# %% [markdown]
# ## Sort Index Values

# %%
# sort_index arranges index values in ascending order
  
df1 = df1.sort_index(level=0)

# %% [markdown]
# ## Check Dataframe

# %%
df1
# Out:
#                                        AMBIENT_AIR_TEMP  TMR_PAV  TMR_SUB_0  \
# SITE_NUMBER OBSERVATION_TIME
# 8           2004-01-18 01:00:00+00:00            -33.90   -24.20     -22.40
#             2004-01-18 02:00:00+00:00            -34.80   -24.50     -22.70
#             2004-01-18 03:00:00+00:00            -35.70   -24.90     -23.10
#             2004-01-18 04:00:00+00:00            -36.00   -25.10     -23.30
#             2004-01-18 05:00:00+00:00            -35.90   -25.20     -23.40
# ...                                                 ...      ...        ...
# 323         2017-12-31 19:00:00+00:00             22.30    22.80      21.14
#             2017-12-31 20:00:00+00:00             22.42    22.41      21.13
#             2017-12-31 21:00:00+00:00             22.58    22.20      21.07
#             2017-12-31 22:00:00+00:00             21.94    22.04      21.00
#             2017-12-31 23:00:00+00:00             21.80    21.83      20.92
#
# ...

# %% [markdown]
# ## Check Datatypes

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 5754574 entries, (8, Timestamp('2004-01-18 01:00:00+0000', tz='UTC')) to (323, Timestamp('2017-12-31 23:00:00+0000', tz='UTC'))
# Data columns (total 17 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   AMBIENT_AIR_TEMP  float64
#  1   TMR_PAV           float64
#  2   TMR_SUB_0         float64
#  3   TMR_SUB_3         float64
#  4   TMR_SUB_6         float64
#  5   TMR_SUB_9         float64
#  6   TMR_SUB_12        float64
#  7   TMR_SUB_18        float64
#  8   TMR_SUB_24        float64
#  9   TMR_SUB_30        float64
#  10  TMR_SUB_36        float64
#  11  TMR_SUB_42        float64
#  12  TMR_SUB_48        float64
#  13  TMR_SUB_54        float64
#  14  TMR_SUB_60        float64
#  15  TMR_SUB_66        float64
#  16  TMR_SUB_72        float64
# dtypes: float64(17)
# memory usage: 778.8 MB

# %% [markdown]
# ## View Range of Index Values

# %%
df1.index
# Out:
# MultiIndex([(  8, '2004-01-18 01:00:00+00:00'),
#             (  8, '2004-01-18 02:00:00+00:00'),
#             (  8, '2004-01-18 03:00:00+00:00'),
#             (  8, '2004-01-18 04:00:00+00:00'),
#             (  8, '2004-01-18 05:00:00+00:00'),
#             (  8, '2004-01-18 06:00:00+00:00'),
#             (  8, '2004-01-18 07:00:00+00:00'),
#             (  8, '2004-01-18 08:00:00+00:00'),
#             (  8, '2004-01-18 09:00:00+00:00'),
#             (  8, '2004-01-18 10:00:00+00:00'),
#             ...
#             (323, '2017-12-31 14:00:00+00:00'),
#             (323, '2017-12-31 15:00:00+00:00'),
#             (323, '2017-12-31 16:00:00+00:00'),
#             (323, '2017-12-31 17:00:00+00:00'),
#             (323, '2017-12-31 18:00:00+00:00'),
#             (323, '2017-12-31 19:00:00+00:00'),
#             (323, '2017-12-31 20:00:00+00:00'),
#             (323, '2017-12-31 21:00:00+00:00'),
#             (323, '2017-12-31 22:00:00+00:00'),
# ...

# %% [markdown]
# ## Test Slicing to Specified SITE_NUMBER and OBSERVATION_TIME Range

# %%
df6 = df1.loc[(128, '2007-01'): (128, '2007-12-31-23')]

# %%
df6
# Out:
#                                        AMBIENT_AIR_TEMP  TMR_PAV  TMR_SUB_0  \
# SITE_NUMBER OBSERVATION_TIME
# 128         2007-01-01 00:00:00+00:00              8.25    16.01      18.61
#             2007-01-01 01:00:00+00:00             10.83    16.01      18.69
#             2007-01-01 02:00:00+00:00             11.22    15.83      18.52
#             2007-01-01 03:00:00+00:00             10.05    15.74      18.08
#             2007-01-01 04:00:00+00:00             11.74    15.46      17.82
# ...                                                 ...      ...        ...
#             2007-12-31 19:00:00+00:00             30.54    24.51      24.51
#             2007-12-31 20:00:00+00:00             31.82    24.91      24.27
#             2007-12-31 21:00:00+00:00             33.34    26.53      24.82
#             2007-12-31 22:00:00+00:00             36.91    26.45      25.05
#             2007-12-31 23:00:00+00:00             36.83    28.62      25.52
#
# ...

# %% [markdown]
# ## Test Slicing Specified SITE_NUMBER Range

# %%
# test slicing specified site_number values (success)

df7 = df1.loc[(101): (128)]

# %%
df7
# Out:
#                                        AMBIENT_AIR_TEMP  TMR_PAV  TMR_SUB_0  \
# SITE_NUMBER OBSERVATION_TIME
# 101         2007-03-27 01:00:00+00:00             23.72    10.58       9.68
#             2007-03-27 02:00:00+00:00             23.90    10.58       9.86
#             2007-03-27 03:00:00+00:00             19.94     9.86       9.68
#             2007-03-27 04:00:00+00:00             10.58     8.96       8.96
#             2007-03-27 05:00:00+00:00              6.62     8.06       8.24
# ...                                                 ...      ...        ...
# 128         2017-12-31 19:00:00+00:00             31.98    25.85      22.62
#             2017-12-31 20:00:00+00:00             31.41    25.73      22.72
#             2017-12-31 21:00:00+00:00             30.78    25.60      22.82
#             2017-12-31 22:00:00+00:00             31.05    25.53      22.91
#             2017-12-31 23:00:00+00:00             31.58    25.95      22.99
#
# ...

# %% [markdown]
# ## Test Slicing SITE_NUMBER Range and Date Time Range

# %%
# second date time argument for station 323 does not seem to function properly (does not return '2014' dates)

df8 = df1.loc[(101,'2014'): (323, '2014')]

# %%
df8
# Out:
#                                        AMBIENT_AIR_TEMP  TMR_PAV  TMR_SUB_0  \
# SITE_NUMBER OBSERVATION_TIME
# 101         2014-01-01 00:00:00+00:00             -6.70    35.06      35.06
#             2014-01-01 01:00:00+00:00             -5.62    31.82      35.06
#             2014-01-01 02:00:00+00:00             -3.82    35.06      31.82
#             2014-01-01 03:00:00+00:00             -3.46    35.06      31.82
#             2014-01-01 04:00:00+00:00             -2.20    31.64      38.66
# ...                                                 ...      ...        ...
# 313         2017-12-31 19:00:00+00:00             22.30    22.80      21.14
#             2017-12-31 20:00:00+00:00             22.42    22.41      21.13
#             2017-12-31 21:00:00+00:00             22.58    22.20      21.07
#             2017-12-31 22:00:00+00:00             21.94    22.04      21.00
#             2017-12-31 23:00:00+00:00             21.80    21.83      20.92
#
# ...

# %%
df8.index
# Out:
# MultiIndex([(101, '2014-01-01 00:00:00+00:00'),
#             (101, '2014-01-01 01:00:00+00:00'),
#             (101, '2014-01-01 02:00:00+00:00'),
#             (101, '2014-01-01 03:00:00+00:00'),
#             (101, '2014-01-01 04:00:00+00:00'),
#             (101, '2014-01-01 05:00:00+00:00'),
#             (101, '2014-01-01 06:00:00+00:00'),
#             (101, '2014-01-01 07:00:00+00:00'),
#             (101, '2014-01-01 08:00:00+00:00'),
#             (101, '2014-01-01 09:00:00+00:00'),
#             ...
#             (128, '2013-12-31 15:00:00+00:00'),
#             (128, '2013-12-31 16:00:00+00:00'),
#             (128, '2013-12-31 17:00:00+00:00'),
#             (128, '2013-12-31 18:00:00+00:00'),
#             (128, '2013-12-31 19:00:00+00:00'),
#             (128, '2013-12-31 20:00:00+00:00'),
#             (128, '2013-12-31 21:00:00+00:00'),
#             (128, '2013-12-31 22:00:00+00:00'),
#             (128, '2013-12-31 23:00:00+00:00'),
# ...

# %% [markdown]
# ## Other Exercises

# %%
# station is integer, but date time is 'object'

df1.index.levels[1]
# Out:
# DatetimeIndex(['2002-04-16 19:00:00+00:00', '2002-04-16 20:00:00+00:00',
#                '2002-04-16 21:00:00+00:00', '2002-04-16 22:00:00+00:00',
#                '2002-04-16 23:00:00+00:00', '2002-04-17 00:00:00+00:00',
#                '2002-04-17 01:00:00+00:00', '2002-04-17 02:00:00+00:00',
#                '2002-04-17 03:00:00+00:00', '2002-04-17 04:00:00+00:00',
#                ...
#                '2017-12-31 14:00:00+00:00', '2017-12-31 15:00:00+00:00',
#                '2017-12-31 16:00:00+00:00', '2017-12-31 17:00:00+00:00',
#                '2017-12-31 18:00:00+00:00', '2017-12-31 19:00:00+00:00',
#                '2017-12-31 20:00:00+00:00', '2017-12-31 21:00:00+00:00',
#                '2017-12-31 22:00:00+00:00', '2017-12-31 23:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='OBSERVATION_TIME', length=127982, freq=None)

# %%
datetimeindex = pd.to_datetime(df1.index.levels[1])

# %%
df1.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-83941e9879da> in <module>
# ----> 1 df1.info()
#
# AttributeError: 'DatetimeIndex' object has no attribute 'info'

# %%
# works but does not reference 128 index column

df2 = df1.loc[(128),('2014')]
# Out:
# C:\Users\TRHislop\Anaconda3\lib\site-packages\pandas\core\generic.py:3723: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   return self[key]

# %%
df1.loc[(df1.SITE_NUMBER == 128) & (df1.OBSERVATION_TIME == '2014-01-01 01:00:00+00:00')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-ac2eb81778a4> in <module>
# ----> 1 df1.loc[(df1.SITE_NUMBER == 128) & (df1.OBSERVATION_TIME == '2014-01-01 01:00:00+00:00')]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'SITE_NUMBER'

# %%
df1.loc[(128), ('2014-01-01 01:00:00+00:00')]
# Out:
# AMBIENT_AIR_TEMP    37.04
# TMR_PAV             30.45
# TMR_SUB_0           29.72
# TMR_SUB_3           28.99
# TMR_SUB_6           28.41
# TMR_SUB_9           28.11
# TMR_SUB_12          27.44
# TMR_SUB_18          26.74
# TMR_SUB_24          25.98
# TMR_SUB_30          25.83
# TMR_SUB_36          25.67
# TMR_SUB_42          25.98
# TMR_SUB_48          26.74
# TMR_SUB_54          28.48
# TMR_SUB_60          29.29
# TMR_SUB_66          29.72
# TMR_SUB_72          30.66
# Name: (128, 2014-01-01 01:00:00+00:00), dtype: float64

# %%
df1.loc[128].head()
# Out:
#                            AMBIENT_AIR_TEMP  TMR_PAV  TMR_SUB_0  TMR_SUB_3  \
# OBSERVATION_TIME
# 2003-01-31 02:00:00+00:00             31.31    31.93      31.85      31.57
# 2003-01-31 03:00:00+00:00             34.11    31.37      32.07      32.14
# 2003-01-31 04:00:00+00:00             32.83    30.87      31.79      31.58
# 2003-01-31 05:00:00+00:00             32.47    31.37      32.15      31.79
# 2003-01-31 06:00:00+00:00             33.89    31.38      32.01      31.80
#
#                            TMR_SUB_6  TMR_SUB_9  TMR_SUB_12  TMR_SUB_18  \
# OBSERVATION_TIME
# 2003-01-31 02:00:00+00:00      31.07      31.07       31.00       30.72
# 2003-01-31 03:00:00+00:00      31.51      30.94       31.23       30.80
# 2003-01-31 04:00:00+00:00      31.30      31.16       30.87       30.52
# 2003-01-31 05:00:00+00:00      31.51      31.37       31.02       30.80
# 2003-01-31 06:00:00+00:00      31.73      31.37       30.80       30.52
#
# ...

# %%
# does appear to match station 128 values despite not including 128 label

df2.head()
# Out:
#                            AMBIENT_AIR_TEMP  TMR_PAV  TMR_SUB_0  TMR_SUB_3  \
# OBSERVATION_TIME
# 2014-01-01 00:00:00+00:00             38.55    26.52      22.58      21.17
# 2014-01-01 01:00:00+00:00             37.04    30.45      29.72      28.99
# 2014-01-01 02:00:00+00:00             36.45    31.16      30.01      29.51
# 2014-01-01 03:00:00+00:00             35.40    30.73      30.08      29.36
# 2014-01-01 04:00:00+00:00             35.50    30.74      29.95      29.36
#
#                            TMR_SUB_6  TMR_SUB_9  TMR_SUB_12  TMR_SUB_18  \
# OBSERVATION_TIME
# 2014-01-01 00:00:00+00:00      20.07      19.82       19.21       19.99
# 2014-01-01 01:00:00+00:00      28.41      28.11       27.44       26.74
# 2014-01-01 02:00:00+00:00      28.63      28.47       27.80       26.52
# 2014-01-01 03:00:00+00:00      28.63      28.26       27.66       26.67
# 2014-01-01 04:00:00+00:00      28.48      28.33       27.74       26.45
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8760 entries, 2014-01-01 00:00:00+00:00 to 2014-12-31 23:00:00+00:00
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   AMBIENT_AIR_TEMP  8760 non-null   float64
#  1   TMR_PAV           8760 non-null   float64
#  2   TMR_SUB_0         8760 non-null   float64
#  3   TMR_SUB_3         8760 non-null   float64
#  4   TMR_SUB_6         8760 non-null   float64
#  5   TMR_SUB_9         8760 non-null   float64
#  6   TMR_SUB_12        8760 non-null   float64
#  7   TMR_SUB_18        8760 non-null   float64
#  8   TMR_SUB_24        8760 non-null   float64
#  9   TMR_SUB_30        8760 non-null   float64
#  10  TMR_SUB_36        8760 non-null   float64
#  11  TMR_SUB_42        8760 non-null   float64
#  12  TMR_SUB_48        8760 non-null   float64
#  13  TMR_SUB_54        8760 non-null   float64
#  14  TMR_SUB_60        8760 non-null   float64
# ...

# %%
df2.index
# Out:
# DatetimeIndex(['2003-01-31 02:00:00+00:00', '2003-01-31 03:00:00+00:00',
#                '2003-01-31 04:00:00+00:00', '2003-01-31 05:00:00+00:00',
#                '2003-01-31 06:00:00+00:00', '2003-01-31 07:00:00+00:00',
#                '2003-01-31 08:00:00+00:00', '2003-01-31 09:00:00+00:00',
#                '2003-01-31 10:00:00+00:00', '2003-01-31 11:00:00+00:00',
#                ...
#                '2017-12-31 14:00:00+00:00', '2017-12-31 15:00:00+00:00',
#                '2017-12-31 16:00:00+00:00', '2017-12-31 17:00:00+00:00',
#                '2017-12-31 18:00:00+00:00', '2017-12-31 19:00:00+00:00',
#                '2017-12-31 20:00:00+00:00', '2017-12-31 21:00:00+00:00',
#                '2017-12-31 22:00:00+00:00', '2017-12-31 23:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='OBSERVATION_TIME', length=110581, freq=None)

# %%
df3 = df1.loc[(128): (2014)]

# %%
df3.head()
# Out:
#                                        AMBIENT_AIR_TEMP  TMR_PAV  TMR_SUB_0  \
# SITE_NUMBER OBSERVATION_TIME
# 128         2003-01-31 02:00:00+00:00             31.31    31.93      31.85
#             2003-01-31 03:00:00+00:00             34.11    31.37      32.07
#             2003-01-31 04:00:00+00:00             32.83    30.87      31.79
#             2003-01-31 05:00:00+00:00             32.47    31.37      32.15
#             2003-01-31 06:00:00+00:00             33.89    31.38      32.01
#
#                                        TMR_SUB_3  TMR_SUB_6  TMR_SUB_9  \
# SITE_NUMBER OBSERVATION_TIME
# 128         2003-01-31 02:00:00+00:00      31.57      31.07      31.07
#             2003-01-31 03:00:00+00:00      32.14      31.51      30.94
#             2003-01-31 04:00:00+00:00      31.58      31.30      31.16
#             2003-01-31 05:00:00+00:00      31.79      31.51      31.37
#             2003-01-31 06:00:00+00:00      31.80      31.73      31.37
#
# ...

# %%
df4 = df1.loc[(128): (2014), 'TMR_SUB_18']

# %%
df4
# Out:
# SITE_NUMBER  OBSERVATION_TIME
# 128          2003-01-31 02:00:00+00:00    30.72
#              2003-01-31 03:00:00+00:00    30.80
#              2003-01-31 04:00:00+00:00    30.52
#              2003-01-31 05:00:00+00:00    30.80
#              2003-01-31 06:00:00+00:00    30.52
#                                           ...
# 323          2017-12-31 19:00:00+00:00    24.07
#              2017-12-31 20:00:00+00:00    24.12
#              2017-12-31 21:00:00+00:00    24.16
#              2017-12-31 22:00:00+00:00    24.21
#              2017-12-31 23:00:00+00:00    24.25
# Name: TMR_SUB_18, Length: 2611880, dtype: float64
